# %% [markdown]
# # Extracting the training data

# %%
import pandas as pd
import mediapipe as mp
import numpy as np
import cv2
from pathlib import Path

# %%
# Autoreload when script is changed
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Single image
# All steps to take on each image.

# %%
from preprocessing import load_image, normalize_body, extract_features

# %%
results=load_image("DATA/training data/training frames/Adho mukha svanasana - Downward-facing Dog/out1891.png")

# %%
def get_landmark(
    name: str, landmarks: mp.framework.formats.landmark_pb2.NormalizedLandmarkList
):
    """Get landmark postition from English name."""
    landmark_names = [
        "nose",
        "left_eye_inner",
        "left_eye",
        "left_eye_outer",
        "right_eye_inner",
        "right_eye",
        "right_eye_outer",
        "left_ear",
        "right_ear",
        "mouth_left",
        "mouth_right",
        "left_shoulder",
        "right_shoulder",
        "left_elbow",
        "right_elbow",
        "left_wrist",
        "right_wrist",
        "left_pinky_1",
        "right_pinky_1",
        "left_index_1",
        "right_index_1",
        "left_thumb_2",
        "right_thumb_2",
        "left_hip",
        "right_hip",
        "left_knee",
        "right_knee",
        "left_ankle",
        "right_ankle",
        "left_heel",
        "right_heel",
        "left_foot_index",
        "right_foot_index",
    ]
    landmark_i = landmarks.landmark[landmark_names.index(name)]
    return np.array([landmark_i.x, landmark_i.y, landmark_i.z])

# %%
get_landmark("right_heel",results)
# Out:
# array([0.21777244, 0.82397199, 0.02456942])

# %%
landmarks=results

# %% [markdown]
# Scale by torso size

# %%
shoulder_center = (
        get_landmark("left_shoulder", landmarks)
        - get_landmark("right_shoulder", landmarks)
    ) / 2.
hip_center = (
    get_landmark("left_hip", landmarks) - get_landmark("right_hip", landmarks)
) / 2.
torso_length=np.linalg.norm(shoulder_center - hip_center)
torso_length
# Out:
# 0.03380091851357698

# %% [markdown]
# Position

# %%
hip_center=np.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-a146feb958a8> in <module>
# ----> 1 hip_center=np.mean()
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# TypeError: _mean_dispatcher() missing 1 required positional argument: 'a'

# %%
extract_features(results)
# Out:
# {'nose_x': 0.4864710867404938,
#  'nose_y': 0.7631848454475403,
#  'nose_z': -0.1341341733932495,
#  'left_shoulder_x': 0.48051291704177856,
#  'left_shoulder_y': 0.6742895245552063,
#  'left_shoulder_z': 0.0020962809212505817,
#  'right_shoulder_x': 0.47153717279434204,
#  'right_shoulder_y': 0.6876236200332642,
#  'right_shoulder_z': -0.24701757729053497,
#  'left_elbow_x': 0.5168930888175964,
#  'left_elbow_y': 0.7699902653694153,
#  'left_elbow_z': 0.06728439778089523,
#  'right_elbow_x': 0.5062335729598999,
#  'right_elbow_y': 0.7998769283294678,
#  'right_elbow_z': -0.35864749550819397,
#  'left_wrist_x': 0.5637400150299072,
#  'left_wrist_y': 0.8274198174476624,
#  'left_wrist_z': -0.01913468725979328,
#  'right_wrist_x': 0.562457799911499,
#  'right_wrist_y': 0.8807313442230225,
#  'right_wrist_z': -0.3748415410518646,
#  'left_thumb_2_x': 0.5777013301849365,
#  'left_thumb_2_y': 0.8407303094863892,
#  'left_thumb_2_z': -0.036507684737443924,
#  'right_thumb_2_x': 0.5762546062469482,
#  'right_thumb_2_y': 0.8803491592407227,
#  'right_thumb_2_z': -0.36880454421043396,
#  'left_hip_x': 0.37073996663093567,
#  'left_hip_y': 0.5300409197807312,
#  'left_hip_z': 0.0918634906411171,
#  'right_hip_x': 0.354210764169693,
#  'right_hip_y': 0.529025673866272,
#  'right_hip_z': -0.0916222482919693,
#  'left_knee_x': 0.31324315071105957,
#  'left_knee_y': 0.6747270822525024,
#  'left_knee_z': 0.13194090127944946,
#  'right_knee_x': 0.3025571405887604,
#  'right_knee_y': 0.6771739721298218,
#  'right_knee_z': -0.032259371131658554,
#  'left_ankle_x': 0.25168296694755554,
#  'left_ankle_y': 0.7857887148857117,
#  'left_ankle_z': 0.20755991339683533,
#  'right_ankle_x': 0.23397207260131836,
#  'right_ankle_y': 0.8003049492835999,
#  'right_ankle_z': 0.025608092546463013,
#  'left_foot_index_x': 0.2744041979312897,
#  'left_foot_index_y': 0.8376192450523376,
#  'left_foot_index_z': 0.1487390547990799,
#  'right_foot_index_x': 0.26216742396354675,
#  'right_foot_index_y': 0.85335373878479,
#  'right_foot_index_z': -0.05193175747990608}

# %% [markdown]
# ## Folder

# %%
data_dir=Path("DATA/training data/training frames/Ananda Balasana - Happy Baby's pose/")

# %%
data=[]
for img_file in data_dir.rglob("*.png"):
    result = {}
    try:
#         split by "-", remerge english splits
        names = img_file.parent.name.split("-")
        if len(names)>1:
            name_sa=names[0].strip()
            name_en='-'.join(names[1:]).strip()
        else:
            name_sa=""
            name_en=img_file.parent.name.strip()
    except:
        continue
        
    result["path"]=img_file.relative_to(data_dir)
    result["name_en"] = name_en
    result["name_sa"] = name_sa
    features = extract_features(normalize_body(load_image(str(img_file.resolve()))))
    result.update(features)
    data.append(result)
df=pd.DataFrame(data)

df
# Out:
#            path            name_en          name_sa    nose_x    nose_y  \
# 0   out3426.png  Happy Baby's pose  Ananda Balasana  0.259185  0.750540
# 1   out3420.png  Happy Baby's pose  Ananda Balasana  0.261161  0.749168
# 2   out3412.png  Happy Baby's pose  Ananda Balasana  0.260090  0.779383
# 3   out3423.png  Happy Baby's pose  Ananda Balasana  0.257745  0.752202
# 4   out3421.png  Happy Baby's pose  Ananda Balasana  0.258415  0.749560
# 5   out3422.png  Happy Baby's pose  Ananda Balasana  0.256720  0.754156
# 6   out3425.png  Happy Baby's pose  Ananda Balasana  0.260354  0.749178
# 7   out3427.png  Happy Baby's pose  Ananda Balasana  0.257719  0.752352
# 8   out3410.png  Happy Baby's pose  Ananda Balasana  0.260790  0.748552
# 9   out3414.png  Happy Baby's pose  Ananda Balasana  0.255945  0.781608
# 10  out3417.png  Happy Baby's pose  Ananda Balasana  0.253665  0.779169
# 11  out3419.png  Happy Baby's pose  Ananda Balasana  0.254391  0.764001
# 12  out3418.png  Happy Baby's pose  Ananda Balasana  0.249782  0.778048
# 13  out3413.png  Happy Baby's pose  Ananda Balasana  0.256462  0.783271
# 14  out3415.png  Happy Baby's pose  Ananda Balasana  0.254454  0.779240
# 15  out3411.png  Happy Baby's pose  Ananda Balasana  0.262836  0.748058
# 16  out3409.png  Happy Baby's pose  Ananda Balasana  0.258183  0.743401
# 17  out3424.png  Happy Baby's pose  Ananda Balasana  0.258145  0.749172
# 18  out3416.png  Happy Baby's pose  Ananda Balasana  0.251939  0.777435
#
#       nose_z  left_shoulder_x  left_shoulder_y  left_shoulder_z  \
# 0   0.047941         0.313201         0.793604         0.203296
# 1  -0.005610         0.317460         0.783379         0.157330
# 2  -0.104383         0.319629         0.783163         0.088244
# 3   0.026634         0.313302         0.794352         0.186946
# 4  -0.028189         0.313127         0.791234         0.129209
# 5  -0.036617         0.310687         0.798432         0.112114
# 6   0.011453         0.316516         0.792482         0.170220
# 7  -0.002080         0.312328         0.794347         0.160660
# 8  -0.024579         0.319660         0.780843         0.135490
# 9  -0.092897         0.309631         0.789089         0.161888
# 10 -0.079567         0.307730         0.781549         0.188744
# 11  0.000434         0.311983         0.798133         0.166690
# 12 -0.059367         0.302410         0.804335         0.157345
# 13 -0.096761         0.318991         0.786484         0.124849
# 14 -0.103065         0.306839         0.784136         0.166350
# 15 -0.054124         0.320946         0.773825         0.112976
# 16 -0.032945         0.318362         0.773328         0.146520
# 17  0.004586         0.314895         0.790474         0.164157
# 18 -0.107649         0.315507         0.787945         0.092459
#
#     right_shoulder_x  ...  left_ankle_z  right_ankle_x  right_ankle_y  \
# 0           0.291816  ...      0.157564       0.367368       0.691544
# 1           0.297237  ...      0.211723       0.381288       0.686149
# 2           0.294020  ...      0.323211       0.317725       0.675931
# 3           0.295531  ...      0.213008       0.369696       0.687414
# 4           0.300702  ...      0.166337       0.377484       0.681945
# 5           0.295035  ...      0.178716       0.371326       0.685368
# 6           0.295536  ...      0.188028       0.369288       0.690337
# 7           0.291869  ...      0.197908       0.369579       0.691571
# 8           0.290761  ...      0.343582       0.323740       0.616592
# 9           0.293438  ...      0.216363       0.351373       0.700784
# 10          0.290716  ...      0.199414       0.362392       0.678886
# 11          0.288085  ...      0.232688       0.365300       0.691715
# 12          0.295104  ...      0.232616       0.359922       0.689745
# 13          0.289054  ...      0.207796       0.330284       0.687721
# 14          0.292077  ...      0.198461       0.354986       0.677941
# 15          0.295297  ...      0.339272       0.336722       0.615611
# 16          0.300493  ...      0.295455       0.379603       0.649768
# 17          0.294343  ...      0.190977       0.366820       0.689784
# 18          0.295528  ...      0.272983       0.335499       0.687988
#
#     right_ankle_z  left_foot_index_x  left_foot_index_y  left_foot_index_z  \
# 0       -0.212104           0.363849           0.624899           0.167184
# 1       -0.126475           0.371731           0.620790           0.215587
# 2       -0.217041           0.326759           0.581382           0.330452
# 3       -0.200061           0.363579           0.630359           0.219495
# 4       -0.201947           0.365057           0.632927           0.138414
# 5       -0.103158           0.364212           0.634090           0.165445
# 6       -0.184368           0.359448           0.631889           0.177968
# 7       -0.192483           0.363915           0.625760           0.192963
# 8       -0.245556           0.318163           0.564208           0.334141
# 9       -0.141447           0.329002           0.632532           0.220321
# 10      -0.087030           0.345035           0.620848           0.210874
# 11      -0.248118           0.352722           0.628623           0.221738
# 12      -0.185980           0.345589           0.640395           0.242465
# 13      -0.190369           0.324028           0.611309           0.201912
# 14      -0.077624           0.333733           0.628562           0.203978
# 15      -0.232971           0.328480           0.566937           0.334675
# 16      -0.180975           0.385030           0.563395           0.277874
# 17      -0.206291           0.358235           0.626714           0.183239
# 18      -0.213930           0.312466           0.627715           0.259713
#
#     right_foot_index_x  right_foot_index_y  right_foot_index_z
# 0             0.355148            0.634648           -0.214231
# 1             0.373821            0.632821           -0.107554
# 2             0.288402            0.638272           -0.251862
# 3             0.360496            0.634790           -0.208907
# 4             0.368182            0.627036           -0.212543
# 5             0.357282            0.642805           -0.096147
# 6             0.358797            0.635046           -0.190910
# 7             0.360837            0.631934           -0.197359
# 8             0.295358            0.587950           -0.309336
# 9             0.331239            0.641035           -0.123244
# 10            0.345545            0.621810           -0.053948
# 11            0.345793            0.648720           -0.265408
# 12            0.345253            0.631576           -0.166523
# 13            0.309450            0.641039           -0.205141
# 14            0.336274            0.631807           -0.036372
# 15            0.314403            0.589017           -0.277719
# 16            0.366270            0.584572           -0.185490
# 17            0.353193            0.635578           -0.217836
# 18            0.303768            0.655945           -0.235806
#
# [19 rows x 60 columns]

# %%
df.value_counts("name_en")
# Out:
# name_en
# Easy Pose                125
# Low Lunge                114
# Half Splits Pose          98
# Downward-facing Dog       46
# Standing Forward Bend     31
# Andrea's Cat              27
# .ipynb_checkpoints        24
# Child's pose              23
# high plank                21
# Happy Baby's pose         19
# Upward-Facing Dog         18
# Cobra Pose                 9
# cow pose                   5
# cat pose                   4
# dtype: int64

# %% [markdown]
# ## Check preprocessed data

# %%
ds=pd.read_csv("output.csv")
ds
# Out:
#      Unnamed: 0           name_en             name_sa    nose_x    nose_y  \
# 0             0  Half Splits Pose  Ardha Hanumanasana  0.581890  0.527894
# 1             1  Half Splits Pose  Ardha Hanumanasana  0.562555  0.646910
# 2             2  Half Splits Pose  Ardha Hanumanasana  0.579493  0.534021
# 3             3  Half Splits Pose  Ardha Hanumanasana  0.575249  0.512026
# 4             4  Half Splits Pose  Ardha Hanumanasana  0.575239  0.504725
# ..          ...               ...                 ...       ...       ...
# 535         535        high plank         Phalakasana  0.657534  0.647592
# 536         536        high plank         Phalakasana  0.629904  0.672581
# 537         537        high plank         Phalakasana  0.636387  0.667703
# 538         538        high plank         Phalakasana  0.642756  0.673534
# 539         539        high plank         Phalakasana  0.631431  0.629653
#
#        nose_z  left_shoulder_x  left_shoulder_y  left_shoulder_z  \
# 0   -0.168950         0.544566         0.609070         0.089030
# 1   -0.019731         0.513664         0.610593         0.159394
# 2   -0.155556         0.545002         0.612555         0.089005
# 3    0.035455         0.518560         0.477142        -0.051971
# 4   -0.107558         0.542487         0.616061         0.086450
# ..        ...              ...              ...              ...
# 535 -0.064799         0.601228         0.600332         0.140197
# 536 -0.131697         0.575665         0.615809         0.077150
# 537 -0.091850         0.582730         0.609366         0.117416
# 538 -0.116394         0.595392         0.609434         0.103701
# 539 -0.092678         0.569160         0.614095         0.124979
#
#      right_shoulder_x  ...  left_ankle_z  right_ankle_x  right_ankle_y  \
# 0            0.514745  ...      0.100718       0.579826       0.870550
# 1            0.517667  ...      0.193861       0.570697       0.859199
# 2            0.516335  ...      0.092996       0.580156       0.868410
# 3            0.545835  ...      0.274690       0.272477       0.812547
# 4            0.516042  ...      0.078715       0.578084       0.864819
# ..                ...  ...           ...            ...            ...
# 535          0.602093  ...      0.343990       0.275735       0.781733
# 536          0.573396  ...      0.372269       0.259888       0.802552
# 537          0.577078  ...      0.413961       0.255379       0.802033
# 538          0.599443  ...      0.262926       0.277865       0.787411
# 539          0.560426  ...      0.270554       0.238752       0.784552
#
#      right_ankle_z  left_foot_index_x  left_foot_index_y  left_foot_index_z  \
# 0        -0.076587           0.261653           0.832126           0.029716
# 1         0.046980           0.267511           0.828272           0.152652
# 2        -0.066033           0.262553           0.832726           0.021859
# 3         0.060813           0.599598           0.818101           0.311058
# 4        -0.083012           0.262293           0.832367          -0.005233
# ..             ...                ...                ...                ...
# 535      -0.053675           0.307514           0.826304           0.307695
# 536      -0.033931           0.302700           0.831161           0.327971
# 537      -0.104536           0.285115           0.824037           0.392816
# 538      -0.055811           0.302497           0.823669           0.183150
# 539      -0.034639           0.263177           0.831592           0.199068
#
#      right_foot_index_x  right_foot_index_y  right_foot_index_z
# 0              0.618466            0.829347           -0.148282
# 1              0.616064            0.836311            0.023429
# 2              0.620628            0.828138           -0.135098
# 3              0.241514            0.855104            0.084337
# 4              0.617623            0.830452           -0.166826
# ..                  ...                 ...                 ...
# 535            0.290173            0.850512           -0.141375
# 536            0.286621            0.862103           -0.125585
# 537            0.252718            0.865890           -0.193863
# 538            0.285557            0.857354           -0.164851
# 539            0.251256            0.848185           -0.134678
#
# [540 rows x 60 columns]

# %%
ds.isna().sum()
# Out:
# Unnamed: 0             0
# name_en                0
# name_sa               27
# nose_x                 3
# nose_y                 3
# nose_z                 3
# left_shoulder_x        3
# left_shoulder_y        3
# left_shoulder_z        3
# right_shoulder_x       3
# right_shoulder_y       3
# right_shoulder_z       3
# left_elbow_x           3
# left_elbow_y           3
# left_elbow_z           3
# right_elbow_x          3
# right_elbow_y          3
# right_elbow_z          3
# left_wrist_x           3
# left_wrist_y           3
# left_wrist_z           3
# right_wrist_x          3
# right_wrist_y          3
# right_wrist_z          3
# left_index_1_x         3
# left_index_1_y         3
# left_index_1_z         3
# right_index_1_x        3
# right_index_1_y        3
# right_index_1_z        3
# left_thumb_2_x         3
# left_thumb_2_y         3
# left_thumb_2_z         3
# right_thumb_2_x        3
# right_thumb_2_y        3
# right_thumb_2_z        3
# left_hip_x             3
# left_hip_y             3
# left_hip_z             3
# right_hip_x            3
# right_hip_y            3
# right_hip_z            3
# left_knee_x            3
# left_knee_y            3
# left_knee_z            3
# right_knee_x           3
# right_knee_y           3
# right_knee_z           3
# left_ankle_x           3
# left_ankle_y           3
# left_ankle_z           3
# right_ankle_x          3
# right_ankle_y          3
# right_ankle_z          3
# left_foot_index_x      3
# left_foot_index_y      3
# left_foot_index_z      3
# right_foot_index_x     3
# right_foot_index_y     3
# right_foot_index_z     3
# dtype: int64

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 60 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          540 non-null    int64
#  1   name_en             540 non-null    object
#  2   name_sa             513 non-null    object
#  3   nose_x              537 non-null    float64
#  4   nose_y              537 non-null    float64
#  5   nose_z              537 non-null    float64
#  6   left_shoulder_x     537 non-null    float64
#  7   left_shoulder_y     537 non-null    float64
#  8   left_shoulder_z     537 non-null    float64
#  9   right_shoulder_x    537 non-null    float64
#  10  right_shoulder_y    537 non-null    float64
#  11  right_shoulder_z    537 non-null    float64
#  12  left_elbow_x        537 non-null    float64
#  13  left_elbow_y        537 non-null    float64
#  14  left_elbow_z        537 non-null    float64
#  15  right_elbow_x       537 non-null    float64
#  16  right_elbow_y       537 non-null    float64
#  17  right_elbow_z       537 non-null    float64
#  18  left_wrist_x        537 non-null    float64
#  19  left_wrist_y        537 non-null    float64
#  20  left_wrist_z        537 non-null    float64
#  21  right_wrist_x       537 non-null    float64
#  22  right_wrist_y       537 non-null    float64
#  23  right_wrist_z       537 non-null    float64
#  24  left_index_1_x      537 non-null    float64
#  25  left_index_1_y      537 non-null    float64
#  26  left_index_1_z      537 non-null    float64
#  27  right_index_1_x     537 non-null    float64
#  28  right_index_1_y     537 non-null    float64
#  29  right_index_1_z     537 non-null    float64
#  30  left_thumb_2_x      537 non-null    float64
#  31  left_thumb_2_y      537 non-null    float64
#  32  left_thumb_2_z      537 non-null    float64
#  33  right_thumb_2_x     537 non-null    float64
#  34  right_thumb_2_y     537 non-null    float64
#  35  right_thumb_2_z     537 non-null    float64
#  36  left_hip_x          537 non-null    float64
#  37  left_hip_y          537 non-null    float64
#  38  left_hip_z          537 non-null    float64
#  39  right_hip_x         537 non-null    float64
#  40  right_hip_y         537 non-null    float64
#  41  right_hip_z         537 non-null    float64
#  42  left_knee_x         537 non-null    float64
#  43  left_knee_y         537 non-null    float64
#  44  left_knee_z         537 non-null    float64
#  45  right_knee_x        537 non-null    float64
#  46  right_knee_y        537 non-null    float64
#  47  right_knee_z        537 non-null    float64
#  48  left_ankle_x        537 non-null    float64
#  49  left_ankle_y        537 non-null    float64
#  50  left_ankle_z        537 non-null    float64
#  51  right_ankle_x       537 non-null    float64
#  52  right_ankle_y       537 non-null    float64
#  53  right_ankle_z       537 non-null    float64
#  54  left_foot_index_x   537 non-null    float64
#  55  left_foot_index_y   537 non-null    float64
#  56  left_foot_index_z   537 non-null    float64
#  57  right_foot_index_x  537 non-null    float64
#  58  right_foot_index_y  537 non-null    float64
#  59  right_foot_index_z  537 non-null    float64
# dtypes: float64(57), int64(1), object(2)
# memory usage: 253.2+ KB

# %%
ds.value_counts("name_en")
# Out:
# name_en
# Easy Pose                125
# Low Lunge                114
# Half Splits Pose          98
# Downward-facing Dog       46
# Standing Forward Bend     31
# Andrea's Cat              27
# Child's pose              23
# high plank                21
# Happy Baby's pose         19
# Upward-Facing Dog         18
# Cobra Pose                 9
# cow pose                   5
# cat pose                   4
# dtype: int64
